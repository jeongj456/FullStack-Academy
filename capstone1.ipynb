# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from datetime import datetime as dt
import seaborn as sns
import sqlite3
import random
import os
import dataquality

# %%
df = pd.read_csv('cc_data.csv')
location = pd.read_csv('location_data.csv')
dataquality.data_check(df)
# Out:
# ### Top 5 Rows
#      index trans_date_trans_time               cc_num  \
# 0   151888      23-03-2019 03:06     3586008444788260
# 1  1185025      10-05-2020 11:28     4671727014157740
# 2    10818      07-01-2019 13:31      377993105397617
# 3   975275      30-01-2020 18:49  4710826438164840000
# 4   346814      12-06-2019 03:04      372382441451095
#
#                          merchant       category     amt    first      last  \
# 0  fraud_Ferry, Lynch and Kautzer       misc_net    1.24  Crystal    Fuller
# 1              fraud_Bogisich Inc    grocery_pos  112.57  Kenneth   Edwards
# 2                fraud_Mohr-Bayer   shopping_net    6.69   Nathan  Martinez
# 3             fraud_Langworth LLC  personal_care  100.69     Juan     Henry
# 4             fraud_Hills-Witting   shopping_net    7.80    Brent   Terrell
#
#   gender                      street  ...      lat      long  city_pop  \
# 0      F          000 Jennifer Mills  ...  47.4974 -122.0107     50489
# ...

# %% [markdown]
# ### Get date ranges
# - First convert data types to datetime

# %%
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
df['dob'] = pd.to_datetime(df['dob'])
df['unix_time'] = pd.to_datetime(df['unix_time'])

min_date_trans = df['trans_date_trans_time'].min()
max_date_trans = df['trans_date_trans_time'].max()

min_date_dob = df['dob'].min()
max_date_dob = df['dob'].max()

print(f'Transaction Date Range: {str(min_date_trans)[:10]} <-> {str(max_date_trans)[:10]}\nDOB Date Range: {str(min_date_dob)[:10]} <-> {str(max_date_dob)[:10]}')
# Out:
# Transaction Date Range: 2019-01-01 <-> 2020-06-21
# DOB Date Range: 1924-10-30 <-> 2005-01-29
